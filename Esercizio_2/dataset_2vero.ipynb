# %%
import nltk
import pandas as pd
from pprint import pprint
from collections import Counter
import random
import difflib
from wordfreq import zipf_frequency
from nltk.corpus import wordnet as wn

# %%
#prendi il primo synset nominale di WordNet associato alla parola "vehicle".
wn.synsets("school", pos="n")
for synset in wn.synsets("school", pos="n"):
    print(synset.name(), "-", synset.definition())
# Out:
# school.n.01 - an educational institution
# school.n.02 - a building where young people receive education
# school.n.03 - the process of being formally educated at a school
# school.n.04 - a body of creative artists or writers or thinkers linked by a similar style or by similar teachers
# school.n.05 - the period of instruction in a school; the time period when school is in session
# school.n.06 - an educational institution's faculty and students
# school.n.07 - a large group of fish

# %%
school = wn.synset("school.n.01")

print(school)
print(school.definition())
print()
# Out:
# Synset('school.n.01')
# an educational institution

# %%
#Analisi esplorativa di iponomi di Theatre nodo 1
for synset in school.hyponyms():
    print(synset.name(), "-", synset.definition())
# Out:
# training_school.n.01 - a school providing practical vocational and technical training
# riding_school.n.01 - a school where horsemanship is taught and practiced
# public_school.n.01 - a tuition free school in the United States supported by taxes and controlled by a school board
# conservatory.n.01 - the faculty and students of a school specializing in one of the fine arts
# direct-grant_school.n.01 - formerly a school that charged tuition fees and also received government grants in return for admitting certain non-paying students who were nominated by the local authorities
# finishing_school.n.01 - a private school for girls that emphasizes training in cultural and social activities
# veterinary_school.n.01 - a school teaching veterinary medicine
# crammer.n.03 - a special school where students are crammed
# dance_school.n.01 - a school where students are taught to dance
# day_school.n.02 - a school giving instruction during the daytime
# ...
